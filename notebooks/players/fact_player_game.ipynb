# %% [markdown]
# Grain: one row per player per game

# %%
import nflreadpy as nfl
import pandas as pd
import polars as pl

# %%
# p_stats = nfl.load_player_stats(seasons=list(range(2000, 2025)))
p_stats = nfl.load_player_stats(seasons=[2024])

# %%
p_stats.head()

# %%
p_stats["ga"]

# %%
players = nfl.load_players()

# %%
p_stats.filter(pl.col("player_id") == "00-0023459")

# %%
players.filter(pl.col("gsis_id") == "00-0023459")

# %%
p_stats.schema

# %%
for name, dtype in p_stats.schema.items():
    print(f"{name} {dtype}")
