# %% [markdown]
# Grain: one row per player

# %%
import nflreadpy as nfl
import pandas as pd
import polars as pl

# %%
players = nfl.load_players()

# %%
players.head()

# %%
players.schema

# %%
player_columns = [
    "gsis_id",
    "nfl_id",
    "display_name",
    "first_name",
    "last_name",
    "birth_date",
    "position",
    "position_group",
    "height",
    "weight",
    "headshot",
    "college_name",
    "rookie_season",
    "last_season",
    "draft_year",
    "draft_round",
    "draft_pick",
    "draft_team",
    "status",
    "years_of_experience",
]
nfl_players = players.select(player_columns)


nfl_players.head()
